# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **João Figueiredo**
#
# I'm a Masters Student

# %% [markdown]
# *I am interested in data science because math statistics and programming were always subjects I was interested in and data science is an interesting way to take business management that I learned in university and apply it in other fields.*

# %% [markdown]
# ### My code is suposed to give the result to 2 plus 2

# %%
2+2
# Out:
# 4

# %% [markdown]
# Videos can be watched by accessing <a href="https://www.youtube.com" target="_blank">this youtube link</a>
#
# ![Youtube logo is here](https://upload.wikimedia.org/wikipedia/commons/b/b8/YouTube_Logo_2017.svg)
